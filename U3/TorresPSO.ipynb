# %% [markdown]
# Una empresa de telecomunicaciones está desplegando torres en una ciudad para mejorar la cobertura posible en una red móvil. Las torres que se instalen tienen un alcance limitado, y cada torre debe ubicarse estratégicamente para maximizar la cobertura, minimizando al mismo tiempo los costos de construcción.
#
# Posibles datos de entrada:
#
# · (xi, yi): son las coordenadas de cada una de las N torres que deben ser colocadas en un área urbana.
#
# · R: Es el radio de cobertura de cada torre (o cualquier variable que represente el alcance de la señal)
#
# · 𝑹𝒎𝒂𝒙: es el radio máximo que pueden tener las torres.
#
# · 𝑵𝒎𝒂𝒙: es el número máximo de torres que puede haber
#
# · (𝑿𝒎𝒊𝒏,𝒀𝒎𝒊𝒏,𝑿𝒎𝒂𝒙,𝒀𝒎𝒂𝒙): son las dimensiones del plano en donde pueden estar las torres.
#
# · [({x0, y0, R, Costo}, {x1,y1, R2, Costo2})]: posible características de un individuo
#
# Función objetivo:
#
# · Maximizar la cobertura de la red móvil.
#
# · Minimizar los costos de construcción y el solapamiento innecesario de torres.
#
# · Una idea de como representar la función objetivo es:
#
# 𝐹(𝑥,𝑦,𝑅)=𝐶𝑜𝑏𝑒𝑟𝑡𝑢𝑟𝑎− 𝜆∗(𝐶𝑜𝑠𝑡𝑜+𝑠𝑜𝑙𝑎𝑝𝑎𝑚𝑖𝑒𝑛𝑡𝑜)
#
# · Donde 𝝀 es un factor de penalización en los costos y solapamiento
#
# Objetivos:
#
# · Encontrar las mejores coordenadas (xi, yi) para cada torre
#
# · Encontrar el mejor radio de cobertura R que maximice la cobertura total.
#
# · Minimizar el costo asociado (Entre más cobertura tiene una torre, más cuesta)
#
# Restricciones:
#
# · Las torres tendrán un máximo de cobertura, donde cada una tendrá un Radio que no exceda ese límite.
#
# · Hay un límite de cuantas torres puede haber.
#
# · Las torres no pueden ser puestas fuera del plano, deben estar dentro del área definida.
#
# · La superposición de coberturas no debe ser excesiva (los radios de las torres no deben coincidir más de un porcentaje).

# %%
import numpy as np

# Datos de entrada
Xmin, Ymin, Xmax, Ymax = 0, 0, 100, 100  # Dimensiones del plano
Rmax = 20  # Radio máximo de cobertura
Nmax = 10  # Número máximo de torres
costo_por_radio = 10  # Costo por unidad de radio
lambda_penalizacion = 0.5  # Factor de penalización
penalizacion_solapamiento = 0.1  # Penalización por solapamiento

# Parámetros del PSO
numero_particulas = 30  # Cantidad de partículas en el enjambre
max_iteraciones = 100  # Número máximo de iteraciones
inercia = 0.7  # Factor de inercia
c1, c2 = 1.5, 1.5  # Coeficientes de aceleración

# Inicializar partículas
posiciones_particulas = np.random.uniform(
    [Xmin, Ymin] * Nmax + [0] * Nmax,
    [Xmax, Ymax] * Nmax + [Rmax] * Nmax,
    (numero_particulas, 3 * Nmax)
)
velocidades_particulas = np.random.uniform(-1, 1, (numero_particulas, 3 * Nmax))
mejor_posicion_local = np.copy(posiciones_particulas)
mejor_posicion_global = None

# Mejor valor encontrado
mejor_valor_local = np.full(numero_particulas, np.inf)
mejor_valor_global = np.inf

# Función para calcular el solapamiento
def calcular_solapamiento(posiciones, radios):
    solapamiento = 0
    for i in range(len(posiciones)):
        for j in range(i + 1, len(posiciones)):
            distancia = np.linalg.norm(np.array(posiciones[i]) - np.array(posiciones[j]))
            if distancia < radios[i] + radios[j]:
                solapamiento += max(0, (radios[i] + radios[j] - distancia))
    return solapamiento

# Función objetivo
def funcion_objetivo(parametros):
    posiciones = parametros[:2 * Nmax].reshape((Nmax, 2))
    radios = parametros[2 * Nmax:]
    
    # Filtrar torres que no están en el plano
    en_limites = (posiciones[:, 0] >= Xmin) & (posiciones[:, 0] <= Xmax) & \
                 (posiciones[:, 1] >= Ymin) & (posiciones[:, 1] <= Ymax)
    posiciones = posiciones[en_limites]
    radios = radios[en_limites]
    
    # Calcular cobertura total
    cobertura = np.pi * np.sum(radios**2)
    
    # Calcular costo
    costo = np.sum(radios * costo_por_radio)
    
    # Penalización por solapamiento
    solapamiento = calcular_solapamiento(posiciones, radios)
    
    # Función objetivo
    return -(cobertura - lambda_penalizacion * (costo + solapamiento))

# PSO principal
for iteracion in range(max_iteraciones):
    print(f"\n--- Iteración {iteracion + 1}/{max_iteraciones} ---")
    for i in range(numero_particulas):
        # Evaluar la función objetivo
        valor = funcion_objetivo(posiciones_particulas[i])
        print(f"  Partícula {i + 1}: Valor función objetivo = {valor:.2f}")
        
        # Actualizar el mejor local
        if valor < mejor_valor_local[i]:
            print(f"    Mejor local actualizado para partícula {i + 1}")
            mejor_valor_local[i] = valor
            mejor_posicion_local[i] = posiciones_particulas[i]
        
        # Actualizar el mejor global
        if valor < mejor_valor_global:
            print(f"    Nuevo mejor global encontrado por partícula {i + 1}")
            mejor_valor_global = valor
            mejor_posicion_global = posiciones_particulas[i]
    
    # Actualizar velocidades y posiciones de las partículas
    for i in range(numero_particulas):
        componente_inercial = inercia * velocidades_particulas[i]
        componente_cognitivo = c1 * np.random.random() * (mejor_posicion_local[i] - posiciones_particulas[i])
        componente_social = c2 * np.random.random() * (mejor_posicion_global - posiciones_particulas[i])
        velocidades_particulas[i] = componente_inercial + componente_cognitivo + componente_social
        posiciones_particulas[i] += velocidades_particulas[i]
        
        # Restringir partículas a los límites
        posiciones_particulas[i] = np.clip(
            posiciones_particulas[i],
            [Xmin, Ymin] * Nmax + [0] * Nmax,
            [Xmax, Ymax] * Nmax + [Rmax] * Nmax
        )

    print(f"Mejor valor global hasta ahora: {-mejor_valor_global:.2f}")

# Resultados
mejores_posiciones = mejor_posicion_global[:2 * Nmax].reshape((Nmax, 2))
mejores_radios = mejor_posicion_global[2 * Nmax:]
posiciones_validas = (mejores_posiciones[:, 0] >= Xmin) & (mejores_posiciones[:, 0] <= Xmax) & \
                     (mejores_posiciones[:, 1] >= Ymin) & (mejores_posiciones[:, 1] <= Ymax)

mejores_posiciones = mejores_posiciones[posiciones_validas]
mejores_radios = mejores_radios[posiciones_validas]

print("\n--- Resultados finales ---")
print("Mejores coordenadas y radios:")
for i, (pos, radio) in enumerate(zip(mejores_posiciones, mejores_radios)):
    print(f"Torre {i + 1}: Posición = {pos}, Radio = {radio:.2f}")
print(f"Valor final de la función objetivo (cobertura - penalizaciones): {-mejor_valor_global:.2f}")
# Out:
# --- Iteración 1/100 ---
#   Partícula 1: Valor función objetivo = -2544.61
#     Mejor local actualizado para partícula 1
#     Nuevo mejor global encontrado por partícula 1
#   Partícula 2: Valor función objetivo = -2862.07
#     Mejor local actualizado para partícula 2
#     Nuevo mejor global encontrado por partícula 2
#   Partícula 3: Valor función objetivo = -5967.33
#     Mejor local actualizado para partícula 3
#     Nuevo mejor global encontrado por partícula 3
#   Partícula 4: Valor función objetivo = -5286.45
#     Mejor local actualizado para partícula 4
#   Partícula 5: Valor función objetivo = -4405.71
#     Mejor local actualizado para partícula 5
#   Partícula 6: Valor función objetivo = -3365.39
#     Mejor local actualizado para partícula 6
#   Partícula 7: Valor función objetivo = -2252.50
#     Mejor local actualizado para partícula 7
#   Partícula 8: Valor función objetivo = -3169.34
#     Mejor local actualizado para partícula 8
#   Partícula 9: Valor función objetivo = -2699.73
#     Mejor local actualizado para partícula 9
#   Partícula 10: Valor función objetivo = -3692.03
#     Mejor local actualizado para partícula 10
#   Partícula 11: Valor función objetivo = -3068.66
#     Mejor local actualizado para partícula 11
#   Partícula 12: Valor función objetivo = -2186.75
#     Mejor local actualizado para partícula 12
#   Partícula 13: Valor función objetivo = -3481.07
#     Mejor local actualizado para partícula 13
#   Partícula 14: Valor función objetivo = -3205.06
#     Mejor local actualizado para partícula 14
#   Partícula 15: Valor función objetivo = -4145.08
#     Mejor local actualizado para partícula 15
#   Partícula 16: Valor función objetivo = -1837.52
#     Mejor local actualizado para partícula 16
#   Partícula 17: Valor función objetivo = -2878.60
#     Mejor local actualizado para partícula 17
#   Partícula 18: Valor función objetivo = -2846.86
#     Mejor local actualizado para partícula 18
#   Partícula 19: Valor función objetivo = -3630.28
#     Mejor local actualizado para partícula 19
#   Partícula 20: Valor función objetivo = -4504.84
#     Mejor local actualizado para partícula 20
#   Partícula 21: Valor función objetivo = -4432.40
#     Mejor local actualizado para partícula 21
#   Partícula 22: Valor función objetivo = -3060.63
#     Mejor local actualizado para partícula 22
#   Partícula 23: Valor función objetivo = -5169.10
#     Mejor local actualizado para partícula 23
#   Partícula 24: Valor función objetivo = -2392.68
#     Mejor local actualizado para partícula 24
#   Partícula 25: Valor función objetivo = -3085.55
#     Mejor local actualizado para partícula 25
#   Partícula 26: Valor función objetivo = -5337.31
#     Mejor local actualizado para partícula 26
#   Partícula 27: Valor función objetivo = -3587.05
#     Mejor local actualizado para partícula 27
#   Partícula 28: Valor función objetivo = -4244.35
#     Mejor local actualizado para partícula 28
#   Partícula 29: Valor función objetivo = -5318.55
#     Mejor local actualizado para partícula 29
#   Partícula 30: Valor función objetivo = -3286.74
#     Mejor local actualizado para partícula 30
# Mejor valor global hasta ahora: 5967.33
#
# --- Iteración 2/100 ---
#   Partícula 1: Valor función objetivo = -4226.12
#     Mejor local actualizado para partícula 1
#   Partícula 2: Valor función objetivo = -3324.80
#     Mejor local actualizado para partícula 2
#   Partícula 3: Valor función objetivo = -5947.17
#   Partícula 4: Valor función objetivo = -5195.56
#   Partícula 5: Valor función objetivo = -8106.51
#     Mejor local actualizado para partícula 5
#     Nuevo mejor global encontrado por partícula 5
#   Partícula 6: Valor función objetivo = -4408.72
#     Mejor local actualizado para partícula 6
#   Partícula 7: Valor función objetivo = -2363.06
#     Mejor local actualizado para partícula 7
#   Partícula 8: Valor función objetivo = -4137.96
#     Mejor local actualizado para partícula 8
#   Partícula 9: Valor función objetivo = -7721.29
#     Mejor local actualizado para partícula 9
#   Partícula 10: Valor función objetivo = -3747.47
#     Mejor local actualizado para partícula 10
#   Partícula 11: Valor función objetivo = -3126.83
#     Mejor local actualizado para partícula 11
#   Partícula 12: Valor función objetivo = -6605.00
#     Mejor local actualizado para partícula 12
#   Partícula 13: Valor función objetivo = -6876.38
#     Mejor local actualizado para partícula 13
#   Partícula 14: Valor función objetivo = -6846.84
#     Mejor local actualizado para partícula 14
#   Partícula 15: Valor función objetivo = -4171.72
#     Mejor local actualizado para partícula 15
#   Partícula 16: Valor función objetivo = -4778.61
#     Mejor local actualizado para partícula 16
#   Partícula 17: Valor función objetivo = -3209.43
#     Mejor local actualizado para partícula 17
#   Partícula 18: Valor función objetivo = -4096.50
#     Mejor local actualizado para partícula 18
#   Partícula 19: Valor función objetivo = -4101.57
#     Mejor local actualizado para partícula 19
#   Partícula 20: Valor función objetivo = -6206.09
#     Mejor local actualizado para partícula 20
#   Partícula 21: Valor función objetivo = -4559.20
#     Mejor local actualizado para partícula 21
#   Partícula 22: Valor función objetivo = -3183.55
#     Mejor local actualizado para partícula 22
#   Partícula 23: Valor función objetivo = -5720.57
#     Mejor local actualizado para partícula 23
#   Partícula 24: Valor función objetivo = -2407.00
#     Mejor local actualizado para partícula 24
#   Partícula 25: Valor función objetivo = -4331.57
#     Mejor local actualizado para partícula 25
#   Partícula 26: Valor función objetivo = -5239.68
#   Partícula 27: Valor función objetivo = -6705.70
#     Mejor local actualizado para partícula 27
#   Partícula 28: Valor función objetivo = -6242.82
#     Mejor local actualizado para partícula 28
#   Partícula 29: Valor función objetivo = -4966.15
#   Partícula 30: Valor función objetivo = -6170.07
#     Mejor local actualizado para partícula 30
# Mejor valor global hasta ahora: 8106.51
#
# --- Iteración 3/100 ---
#   Partícula 1: Valor función objetivo = -8779.56
#     Mejor local actualizado para partícula 1
#     Nuevo mejor global encontrado por partícula 1
#   Partícula 2: Valor función objetivo = -6572.16
#     Mejor local actualizado para partícula 2
#   Partícula 3: Valor función objetivo = -8383.58
#     Mejor local actualizado para partícula 3
#   Partícula 4: Valor función objetivo = -8379.70
#     Mejor local actualizado para partícula 4
#   Partícula 5: Valor función objetivo = -8769.03
#     Mejor local actualizado para partícula 5
#   Partícula 6: Valor función objetivo = -8650.57
#     Mejor local actualizado para partícula 6
#   Partícula 7: Valor función objetivo = -8799.94
#     Mejor local actualizado para partícula 7
#     Nuevo mejor global encontrado por partícula 7
#   Partícula 8: Valor función objetivo = -8914.36
#     Mejor local actualizado para partícula 8
#     Nuevo mejor global encontrado por partícula 8
#   Partícula 9: Valor función objetivo = -8380.06
#     Mejor local actualizado para partícula 9
#   Partícula 10: Valor función objetivo = -4032.73
#     Mejor local actualizado para partícula 10
#   Partícula 11: Valor función objetivo = -3191.02
#     Mejor local actualizado para partícula 11
#   Partícula 12: Valor función objetivo = -8291.12
#     Mejor local actualizado para partícula 12
#   Partícula 13: Valor función objetivo = -8805.46
#     Mejor local actualizado para partícula 13
#   Partícula 14: Valor función objetivo = -8396.95
#     Mejor local actualizado para partícula 14
#   Partícula 15: Valor función objetivo = -4339.65
#     Mejor local actualizado para partícula 15
#   Partícula 16: Valor función objetivo = -8856.11
#     Mejor local actualizado para partícula 16
#   Partícula 17: Valor función objetivo = -9208.21
#     Mejor local actualizado para partícula 17
#     Nuevo mejor global encontrado por partícula 17
#   Partícula 18: Valor función objetivo = -7093.66
#     Mejor local actualizado para partícula 18
#   Partícula 19: Valor función objetivo = -8800.80
#     Mejor local actualizado para partícula 19
#   Partícula 20: Valor función objetivo = -8780.84
#     Mejor local actualizado para partícula 20
#   Partícula 21: Valor función objetivo = -8721.79
#     Mejor local actualizado para partícula 21
#   Partícula 22: Valor función objetivo = -8905.70
#     Mejor local actualizado para partícula 22
#   Partícula 23: Valor función objetivo = -8813.49
#     Mejor local actualizado para partícula 23
#   Partícula 24: Valor función objetivo = -8886.82
#     Mejor local actualizado para partícula 24
#   Partícula 25: Valor función objetivo = -9148.35
#     Mejor local actualizado para partícula 25
#   Partícula 26: Valor función objetivo = -8663.10
#     Mejor local actualizado para partícula 26
#   Partícula 27: Valor función objetivo = -8134.21
#     Mejor local actualizado para partícula 27
#   Partícula 28: Valor función objetivo = -8815.36
#     Mejor local actualizado para partícula 28
#   Partícula 29: Valor función objetivo = -5925.64
#     Mejor local actualizado para partícula 29
#   Partícula 30: Valor función objetivo = -8254.46
#     Mejor local actualizado para partícula 30
# Mejor valor global hasta ahora: 9208.21
#
# --- Iteración 4/100 ---
#   Partícula 1: Valor función objetivo = -9193.12
#     Mejor local actualizado para partícula 1
#   Partícula 2: Valor función objetivo = -9207.56
#     Mejor local actualizado para partícula 2
#   Partícula 3: Valor función objetivo = -8955.07
#     Mejor local actualizado para partícula 3
#   Partícula 4: Valor función objetivo = -8696.70
#     Mejor local actualizado para partícula 4
#   Partícula 5: Valor función objetivo = -8803.36
#     Mejor local actualizado para partícula 5
#   Partícula 6: Valor función objetivo = -8914.46
#     Mejor local actualizado para partícula 6
#   Partícula 7: Valor función objetivo = -9201.01
#     Mejor local actualizado para partícula 7
#   Partícula 8: Valor función objetivo = -9168.02
#     Mejor local actualizado para partícula 8
#   Partícula 9: Valor función objetivo = -8644.76
#     Mejor local actualizado para partícula 9
#   Partícula 10: Valor función objetivo = -7201.44
#     Mejor local actualizado para partícula 10
#   Partícula 11: Valor función objetivo = -5788.54
#     Mejor local actualizado para partícula 11
#   Partícula 12: Valor función objetivo = -9220.66
#     Mejor local actualizado para partícula 12
#     Nuevo mejor global encontrado por partícula 12
#   Partícula 13: Valor función objetivo = -9197.39
#     Mejor local actualizado para partícula 13
#   Partícula 14: Valor función objetivo = -9206.25
#     Mejor local actualizado para partícula 14
#   Partícula 15: Valor función objetivo = -5714.66
#     Mejor local actualizado para partícula 15
#   Partícula 16: Valor función objetivo = -9120.23
#     Mejor local actualizado para partícula 16
#   Partícula 17: Valor función objetivo = -9206.90
#   Partícula 18: Valor función objetivo = -9178.30
#     Mejor local actualizado para partícula 18
#   Partícula 19: Valor función objetivo = -8958.48
#     Mejor local actualizado para partícula 19
#   Partícula 20: Valor función objetivo = -9045.97
#     Mejor local actualizado para partícula 20
#   Partícula 21: Valor función objetivo = -9133.96
#     Mejor local actualizado para partícula 21
#   Partícula 22: Valor función objetivo = -9191.87
#     Mejor local actualizado para partícula 22
#   Partícula 23: Valor función objetivo = -9186.39
#     Mejor local actualizado para partícula 23
#   Partícula 24: Valor función objetivo = -9162.96
#     Mejor local actualizado para partícula 24
#   Partícula 25: Valor función objetivo = -9174.16
#     Mejor local actualizado para partícula 25
#   Partícula 26: Valor función objetivo = -9183.80
#     Mejor local actualizado para partícula 26
#   Partícula 27: Valor función objetivo = -9185.88
#     Mejor local actualizado para partícula 27
#   Partícula 28: Valor función objetivo = -9216.95
#     Mejor local actualizado para partícula 28
#   Partícula 29: Valor función objetivo = -7777.94
#     Mejor local actualizado para partícula 29
#   Partícula 30: Valor función objetivo = -8969.36
#     Mejor local actualizado para partícula 30
# Mejor valor global hasta ahora: 9220.66
#
# --- Iteración 5/100 ---
#   Partícula 1: Valor función objetivo = -9197.45
#     Mejor local actualizado para partícula 1
#   Partícula 2: Valor función objetivo = -9206.65
#   Partícula 3: Valor función objetivo = -9071.34
#     Mejor local actualizado para partícula 3
#   Partícula 4: Valor función objetivo = -9211.60
#     Mejor local actualizado para partícula 4
#   Partícula 5: Valor función objetivo = -8963.14
#     Mejor local actualizado para partícula 5
#   Partícula 6: Valor función objetivo = -8985.19
#     Mejor local actualizado para partícula 6
#   Partícula 7: Valor función objetivo = -9215.82
#     Mejor local actualizado para partícula 7
#   Partícula 8: Valor función objetivo = -9217.36
#     Mejor local actualizado para partícula 8
#   Partícula 9: Valor función objetivo = -9166.26
#     Mejor local actualizado para partícula 9
#   Partícula 10: Valor función objetivo = -9209.70
#     Mejor local actualizado para partícula 10
#   Partícula 11: Valor función objetivo = -9222.20
#     Mejor local actualizado para partícula 11
#     Nuevo mejor global encontrado por partícula 11
#   Partícula 12: Valor función objetivo = -9199.95
#   Partícula 13: Valor función objetivo = -9186.42
#   Partícula 14: Valor función objetivo = -9174.37
#   Partícula 15: Valor función objetivo = -7791.76
#     Mejor local actualizado para partícula 15
#   Partícula 16: Valor función objetivo = -9187.39
#     Mejor local actualizado para partícula 16
#   Partícula 17: Valor función objetivo = -9187.37
#   Partícula 18: Valor función objetivo = -9184.09
#     Mejor local actualizado para partícula 18
#   Partícula 19: Valor función objetivo = -9156.73
#     Mejor local actualizado para partícula 19
#   Partícula 20: Valor función objetivo = -9195.88
#     Mejor local actualizado para partícula 20
#   Partícula 21: Valor función objetivo = -9167.40
#     Mejor local actualizado para partícula 21
#   Partícula 22: Valor función objetivo = -9182.71
#   Partícula 23: Valor función objetivo = -9193.20
#     Mejor local actualizado para partícula 23
#   Partícula 24: Valor función objetivo = -9150.32
#   Partícula 25: Valor función objetivo = -9185.21
#     Mejor local actualizado para partícula 25
#   Partícula 26: Valor función objetivo = -9180.41
#   Partícula 27: Valor función objetivo = -9184.66
#   Partícula 28: Valor función objetivo = -9168.92
#   Partícula 29: Valor función objetivo = -9176.83
#     Mejor local actualizado para partícula 29
#   Partícula 30: Valor función objetivo = -9195.45
#     Mejor local actualizado para partícula 30
# Mejor valor global hasta ahora: 9222.20
#
# --- Iteración 6/100 ---
#   Partícula 1: Valor función objetivo = -9207.07
#     Mejor local actualizado para partícula 1
#   Partícula 2: Valor función objetivo = -9220.96
#     Mejor local actualizado para partícula 2
#   Partícula 3: Valor función objetivo = -9223.53
#     Mejor local actualizado para partícula 3
#     Nuevo mejor global encontrado por partícula 3
#   Partícula 4: Valor función objetivo = -9224.90
#     Mejor local actualizado para partícula 4
#     Nuevo mejor global encontrado por partícula 4
#   Partícula 5: Valor función objetivo = -9224.19
#     Mejor local actualizado para partícula 5
#   Partícula 6: Valor función objetivo = -9219.68
#     Mejor local actualizado para partícula 6
#   Partícula 7: Valor función objetivo = -9218.24
#     Mejor local actualizado para partícula 7
#   Partícula 8: Valor función objetivo = -9205.23
#   Partícula 9: Valor función objetivo = -9226.32
#     Mejor local actualizado para partícula 9
#     Nuevo mejor global encontrado por partícula 9
#   Partícula 10: Valor función objetivo = -9220.39
#     Mejor local actualizado para partícula 10
#   Partícula 11: Valor función objetivo = -9221.86
#   Partícula 12: Valor función objetivo = -9212.85
#   Partícula 13: Valor función objetivo = -9212.60
#     Mejor local actualizado para partícula 13
#   Partícula 14: Valor función objetivo = -9211.87
#     Mejor local actualizado para partícula 14
#   Partícula 15: Valor función objetivo = -9206.64
#     Mejor local actualizado para partícula 15
#   Partícula 16: Valor función objetivo = -9213.41
#     Mejor local actualizado para partícula 16
#   Partícula 17: Valor función objetivo = -9213.48
#     Mejor local actualizado para partícula 17
#   Partícula 18: Valor función objetivo = -9169.15
#   Partícula 19: Valor función objetivo = -9184.06
#     Mejor local actualizado para partícula 19
#   Partícula 20: Valor función objetivo = -9181.34
#   Partícula 21: Valor función objetivo = -9220.00
#     Mejor local actualizado para partícula 21
#   Partícula 22: Valor función objetivo = -9227.74
#     Mejor local actualizado para partícula 22
#     Nuevo mejor global encontrado por partícula 22
#   Partícula 23: Valor función objetivo = -9191.63
#   Partícula 24: Valor función objetivo = -9206.93
#     Mejor local actualizado para partícula 24
#   Partícula 25: Valor función objetivo = -9181.40
#   Partícula 26: Valor función objetivo = -9188.45
#     Mejor local actualizado para partícula 26
#   Partícula 27: Valor función objetivo = -9196.85
#     Mejor local actualizado para partícula 27
#   Partícula 28: Valor función objetivo = -9194.77
#   Partícula 29: Valor función objetivo = -9206.99
#     Mejor local actualizado para partícula 29
#   Partícula 30: Valor función objetivo = -9210.70
#     Mejor local actualizado para partícula 30
# Mejor valor global hasta ahora: 9227.74
#
# --- Iteración 7/100 ---
#   Partícula 1: Valor función objetivo = -9210.79
#     Mejor local actualizado para partícula 1
#   Partícula 2: Valor función objetivo = -9218.28
#   Partícula 3: Valor función objetivo = -9197.46
#   Partícula 4: Valor función objetivo = -9207.94
#   Partícula 5: Valor función objetivo = -9198.48
#   Partícula 6: Valor función objetivo = -9128.46
#   Partícula 7: Valor función objetivo = -9219.89
#     Mejor local actualizado para partícula 7
#   Partícula 8: Valor función objetivo = -9228.47
#     Mejor local actualizado para partícula 8
#     Nuevo mejor global encontrado por partícula 8
#   Partícula 9: Valor función objetivo = -9205.47
#   Partícula 10: Valor función objetivo = -9223.10
#     Mejor local actualizado para partícula 10
#   Partícula 11: Valor función objetivo = -9224.18
#     Mejor local actualizado para partícula 11
#   Partícula 12: Valor función objetivo = -9199.54
#   Partícula 13: Valor función objetivo = -9141.87
#   Partícula 14: Valor función objetivo = -9157.17
#   Partícula 15: Valor función objetivo = -9163.43
#   Partícula 16: Valor función objetivo = -9191.09
#   Partícula 17: Valor función objetivo = -9181.62
#   Partícula 18: Valor función objetivo = -9214.12
#     Mejor local actualizado para partícula 18
#   Partícula 19: Valor función objetivo = -9207.92
#     Mejor local actualizado para partícula 19
#   Partícula 20: Valor función objetivo = -9208.94
#     Mejor local actualizado para partícula 20
#   Partícula 21: Valor función objetivo = -9193.86
#   Partícula 22: Valor función objetivo = -9176.27
#   Partícula 23: Valor función objetivo = -9198.76
#     Mejor local actualizado para partícula 23
#   Partícula 24: Valor función objetivo = -9128.50
#   Partícula 25: Valor función objetivo = -9160.19
#   Partícula 26: Valor función objetivo = -9148.41
#   Partícula 27: Valor función objetivo = -9211.74
#     Mejor local actualizado para partícula 27
#   Partícula 28: Valor función objetivo = -9207.83
#   Partícula 29: Valor función objetivo = -9157.41
#   Partícula 30: Valor función objetivo = -9148.74
# Mejor valor global hasta ahora: 9228.47
#
# --- Iteración 8/100 ---
#   Partícula 1: Valor función objetivo = -9186.66
#   Partícula 2: Valor función objetivo = -9206.87
#   Partícula 3: Valor función objetivo = -9212.88
#   Partícula 4: Valor función objetivo = -9224.49
#   Partícula 5: Valor función objetivo = -9222.41
#   Partícula 6: Valor función objetivo = -9132.30
#   Partícula 7: Valor función objetivo = -9221.20
#     Mejor local actualizado para partícula 7
#   Partícula 8: Valor función objetivo = -9223.50
#   Partícula 9: Valor función objetivo = -9223.17
#   Partícula 10: Valor función objetivo = -9221.13
#   Partícula 11: Valor función objetivo = -9225.75
#     Mejor local actualizado para partícula 11
#   Partícula 12: Valor función objetivo = -9186.88
#   Partícula 13: Valor función objetivo = -9183.37
#   Partícula 14: Valor función objetivo = -9216.63
#     Mejor local actualizado para partícula 14
#   Partícula 15: Valor función objetivo = -9214.66
#     Mejor local actualizado para partícula 15
#   Partícula 16: Valor función objetivo = -9222.58
#     Mejor local actualizado para partícula 16
#   Partícula 17: Valor función objetivo = -9169.82
#   Partícula 18: Valor función objetivo = -9200.18
#   Partícula 19: Valor función objetivo = -9214.81
#     Mejor local actualizado para partícula 19
#   Partícula 20: Valor función objetivo = -9225.73
#     Mejor local actualizado para partícula 20
#   Partícula 21: Valor función objetivo = -9221.90
#     Mejor local actualizado para partícula 21
#   Partícula 22: Valor función objetivo = -9191.54
#   Partícula 23: Valor función objetivo = -9223.63
#     Mejor local actualizado para partícula 23
#   Partícula 24: Valor función objetivo = -9203.85
#   Partícula 25: Valor función objetivo = -9221.76
#     Mejor local actualizado para partícula 25
#   Partícula 26: Valor función objetivo = -9176.96
#   Partícula 27: Valor función objetivo = -9210.80
#   Partícula 28: Valor función objetivo = -9219.02
#     Mejor local actualizado para partícula 28
#   Partícula 29: Valor función objetivo = -9146.67
#   Partícula 30: Valor función objetivo = -9217.11
#     Mejor local actualizado para partícula 30
# Mejor valor global hasta ahora: 9228.47
#
# --- Iteración 9/100 ---
#   Partícula 1: Valor función objetivo = -9224.27
#     Mejor local actualizado para partícula 1
#   Partícula 2: Valor función objetivo = -9196.70
#   Partícula 3: Valor función objetivo = -9200.09
#   Partícula 4: Valor función objetivo = -9222.61
#   Partícula 5: Valor función objetivo = -9220.03
#   Partícula 6: Valor función objetivo = -9196.67
#   Partícula 7: Valor función objetivo = -9213.60
#   Partícula 8: Valor función objetivo = -9222.46
#   Partícula 9: Valor función objetivo = -9213.86
#   Partícula 10: Valor función objetivo = -9223.37
#     Mejor local actualizado para partícula 10
#   Partícula 11: Valor función objetivo = -9226.59
#     Mejor local actualizado para partícula 11
#   Partícula 12: Valor función objetivo = -9221.81
#     Mejor local actualizado para partícula 12
#   Partícula 13: Valor función objetivo = -9157.47
#   Partícula 14: Valor función objetivo = -9177.15
#   Partícula 15: Valor función objetivo = -9197.05
#   Partícula 16: Valor función objetivo = -9193.82
#   Partícula 17: Valor función objetivo = -9200.56
#   Partícula 18: Valor función objetivo = -9198.76
#   Partícula 19: Valor función objetivo = -9191.85
#   Partícula 20: Valor función objetivo = -9220.93
#   Partícula 21: Valor función objetivo = -9195.31
#   Partícula 22: Valor función objetivo = -9199.48
#   Partícula 23: Valor función objetivo = -9211.06
#   Partícula 24: Valor función objetivo = -9169.66
#   Partícula 25: Valor función objetivo = -9176.83
#   Partícula 26: Valor función objetivo = -9169.18
#   Partícula 27: Valor función objetivo = -9219.91
#     Mejor local actualizado para partícula 27
#   Partícula 28: Valor función objetivo = -9207.22
#   Partícula 29: Valor función objetivo = -9199.50
#   Partícula 30: Valor función objetivo = -9202.30
# Mejor valor global hasta ahora: 9228.47
#
# --- Iteración 10/100 ---
#   Partícula 1: Valor función objetivo = -9207.80
#   Partícula 2: Valor función objetivo = -9181.37
#   Partícula 3: Valor función objetivo = -9210.09
#   Partícula 4: Valor función objetivo = -9220.42
#   Partícula 5: Valor función objetivo = -9221.54
#   Partícula 6: Valor función objetivo = -9178.98
#   Partícula 7: Valor función objetivo = -9226.60
#     Mejor local actualizado para partícula 7
#   Partícula 8: Valor función objetivo = -9223.83
#   Partícula 9: Valor función objetivo = -9205.47
#   Partícula 10: Valor función objetivo = -9223.78
#     Mejor local actualizado para partícula 10
#   Partícula 11: Valor función objetivo = -9227.66
#     Mejor local actualizado para partícula 11
#   Partícula 12: Valor función objetivo = -9222.85
#     Mejor local actualizado para partícula 12
#   Partícula 13: Valor función objetivo = -9188.94
#   Partícula 14: Valor función objetivo = -9173.84
#   Partícula 15: Valor función objetivo = -9223.34
#     Mejor local actualizado para partícula 15
#   Partícula 16: Valor función objetivo = -9223.17
#     Mejor local actualizado para partícula 16
#   Partícula 17: Valor función objetivo = -9218.50
#     Mejor local actualizado para partícula 17
#   Partícula 18: Valor función objetivo = -9216.77
#     Mejor local actualizado para partícula 18
#   Partícula 19: Valor función objetivo = -9224.33
#     Mejor local actualizado para partícula 19
#   Partícula 20: Valor función objetivo = -9217.43
#   Partícula 21: Valor función objetivo = -9220.98
#   Partícula 22: Valor función objetivo = -9215.57
#   Partícula 23: Valor función objetivo = -9201.87
#   Partícula 24: Valor función objetivo = -9220.44
#     Mejor local actualizado para partícula 24
#   Partícula 25: Valor función objetivo = -9217.82
#   Partícula 26: Valor función objetivo = -9201.39
#     Mejor local actualizado para partícula 26
#   Partícula 27: Valor función objetivo = -9220.37
#     Mejor local actualizado para partícula 27
#   Partícula 28: Valor función objetivo = -9207.62
#   Partícula 29: Valor función objetivo = -9179.17
#   Partícula 30: Valor función objetivo = -9216.78
# Mejor valor global hasta ahora: 9228.47
#
# --- Iteración 11/100 ---
#   Partícula 1: Valor función objetivo = -9198.37
#   Partícula 2: Valor función objetivo = -9227.46
#     Mejor local actualizado para partícula 2
#   Partícula 3: Valor función objetivo = -9174.14
#   Partícula 4: Valor función objetivo = -9221.92
#   Partícula 5: Valor función objetivo = -9224.41
#     Mejor local actualizado para partícula 5
#   Partícula 6: Valor función objetivo = -9207.28
#   Partícula 7: Valor función objetivo = -9211.69
#   Partícula 8: Valor función objetivo = -9215.09
#   Partícula 9: Valor función objetivo = -9200.25
#   Partícula 10: Valor función objetivo = -9219.83
#   Partícula 11: Valor función objetivo = -9226.70
#   Partícula 12: Valor función objetivo = -9223.90
#     Mejor local actualizado para partícula 12
#   Partícula 13: Valor función objetivo = -9159.23
#   Partícula 14: Valor función objetivo = -9214.79
#   Partícula 15: Valor función objetivo = -9199.48
#   Partícula 16: Valor función objetivo = -9201.22
#   Partícula 17: Valor función objetivo = -9206.04
#   Partícula 18: Valor función objetivo = -9187.90
#   Partícula 19: Valor función objetivo = -9223.41
#   Partícula 20: Valor función objetivo = -9216.90
#   Partícula 21: Valor función objetivo = -9207.81
#   Partícula 22: Valor función objetivo = -9158.97
#   Partícula 23: Valor función objetivo = -9214.75
#   Partícula 24: Valor función objetivo = -9165.80
#   Partícula 25: Valor función objetivo = -9197.30
#   Partícula 26: Valor función objetivo = -9211.72
#     Mejor local actualizado para partícula 26
#   Partícula 27: Valor función objetivo = -9211.50
#   Partícula 28: Valor función objetivo = -9211.03
#   Partícula 29: Valor función objetivo = -9192.37
#   Partícula 30: Valor función objetivo = -9175.92
# Mejor valor global hasta ahora: 9228.47
#
# --- Iteración 12/100 ---
#   Partícula 1: Valor función objetivo = -9178.25
#   Partícula 2: Valor función objetivo = -9159.74
#   Partícula 3: Valor función objetivo = -9196.62
#   Partícula 4: Valor función objetivo = -9204.68
#   Partícula 5: Valor función objetivo = -9192.07
#   Partícula 6: Valor función objetivo = -9175.92
#   Partícula 7: Valor función objetivo = -9228.66
#     Mejor local actualizado para partícula 7
#     Nuevo mejor global encontrado por partícula 7
#   Partícula 8: Valor función objetivo = -9218.62
#   Partícula 9: Valor función objetivo = -9213.49
#   Partícula 10: Valor función objetivo = -9224.80
#     Mejor local actualizado para partícula 10
#   Partícula 11: Valor función objetivo = -9224.52
#   Partícula 12: Valor función objetivo = -9220.73
#   Partícula 13: Valor función objetivo = -9121.47
#   Partícula 14: Valor función objetivo = -9219.62
#     Mejor local actualizado para partícula 14
#   Partícula 15: Valor función objetivo = -9226.12
#     Mejor local actualizado para partícula 15
#   Partícula 16: Valor función objetivo = -9227.48
#     Mejor local actualizado para partícula 16
#   Partícula 17: Valor función objetivo = -9223.62
#     Mejor local actualizado para partícula 17
#   Partícula 18: Valor función objetivo = -9199.38
#   Partícula 19: Valor función objetivo = -9220.64
#   Partícula 20: Valor función objetivo = -9218.21
#   Partícula 21: Valor función objetivo = -9218.63
#   Partícula 22: Valor función objetivo = -9160.24
#   Partícula 23: Valor función objetivo = -9214.53
#   Partícula 24: Valor función objetivo = -9168.45
#   Partícula 25: Valor función objetivo = -9229.63
#     Mejor local actualizado para partícula 25
#     Nuevo mejor global encontrado por partícula 25
#   Partícula 26: Valor función objetivo = -9183.57
#   Partícula 27: Valor función objetivo = -9209.68
#   Partícula 28: Valor función objetivo = -9219.95
#     Mejor local actualizado para partícula 28
#   Partícula 29: Valor función objetivo = -9163.86
#   Partícula 30: Valor función objetivo = -9213.07
# Mejor valor global hasta ahora: 9229.63
#
# --- Iteración 13/100 ---
#   Partícula 1: Valor función objetivo = -9224.37
#     Mejor local actualizado para partícula 1
#   Partícula 2: Valor función objetivo = -9207.52
#   Partícula 3: Valor función objetivo = -9222.62
#   Partícula 4: Valor función objetivo = -9201.80
#   Partícula 5: Valor función objetivo = -9231.19
#     Mejor local actualizado para partícula 5
#     Nuevo mejor global encontrado por partícula 5
#   Partícula 6: Valor función objetivo = -9208.91
#   Partícula 7: Valor función objetivo = -9219.32
#   Partícula 8: Valor función objetivo = -9232.58
#     Mejor local actualizado para partícula 8
#     Nuevo mejor global encontrado por partícula 8
#   Partícula 9: Valor función objetivo = -9227.49
#     Mejor local actualizado para partícula 9
#   Partícula 10: Valor función objetivo = -9229.66
#     Mejor local actualizado para partícula 10
#   Partícula 11: Valor función objetivo = -9231.28
#     Mejor local actualizado para partícula 11
#   Partícula 12: Valor función objetivo = -9230.21
#     Mejor local actualizado para partícula 12
#   Partícula 13: Valor función objetivo = -9198.13
#   Partícula 14: Valor función objetivo = -9221.56
#     Mejor local actualizado para partícula 14
#   Partícula 15: Valor función objetivo = -9211.77
#   Partícula 16: Valor función objetivo = -9227.65
#     Mejor local actualizado para partícula 16
#   Partícula 17: Valor función objetivo = -9210.52
#   Partícula 18: Valor función objetivo = -9191.17
#   Partícula 19: Valor función objetivo = -9227.69
#     Mejor local actualizado para partícula 19
#   Partícula 20: Valor función objetivo = -9208.40
#   Partícula 21: Valor función objetivo = -9223.31
#     Mejor local actualizado para partícula 21
#   Partícula 22: Valor función objetivo = -9197.13
#   Partícula 23: Valor función objetivo = -9215.20
#   Partícula 24: Valor función objetivo = -9211.50
#   Partícula 25: Valor función objetivo = -9211.26
#   Partícula 26: Valor función objetivo = -9183.87
#   Partícula 27: Valor función objetivo = -9218.91
#   Partícula 28: Valor función objetivo = -9200.80
#   Partícula 29: Valor función objetivo = -9189.93
#   Partícula 30: Valor función objetivo = -9196.49
# Mejor valor global hasta ahora: 9232.58
#
# --- Iteración 14/100 ---
#   Partícula 1: Valor función objetivo = -9181.10
#   Partícula 2: Valor función objetivo = -9176.86
#   Partícula 3: Valor función objetivo = -9204.39
#   Partícula 4: Valor función objetivo = -9173.10
#   Partícula 5: Valor función objetivo = -9199.29
#   Partícula 6: Valor función objetivo = -9202.09
#   Partícula 7: Valor función objetivo = -9214.32
#   Partícula 8: Valor función objetivo = -9216.91
#   Partícula 9: Valor función objetivo = -9204.26
#   Partícula 10: Valor función objetivo = -9229.33
#   Partícula 11: Valor función objetivo = -9201.23
#   Partícula 12: Valor función objetivo = -9225.75
#   Partícula 13: Valor función objetivo = -9178.99
#   Partícula 14: Valor función objetivo = -9204.07
#   Partícula 15: Valor función objetivo = -9216.74
#   Partícula 16: Valor función objetivo = -9198.20
#   Partícula 17: Valor función objetivo = -9200.45
#   Partícula 18: Valor función objetivo = -9217.22
#     Mejor local actualizado para partícula 18
#   Partícula 19: Valor función objetivo = -9219.78
#   Partícula 20: Valor función objetivo = -9191.40
#   Partícula 21: Valor función objetivo = -9190.80
#   Partícula 22: Valor función objetivo = -9181.88
#   Partícula 23: Valor función objetivo = -9203.28
#   Partícula 24: Valor función objetivo = -9175.10
#   Partícula 25: Valor función objetivo = -9201.00
#   Partícula 26: Valor función objetivo = -9194.21
#   Partícula 27: Valor función objetivo = -9201.04
#   Partícula 28: Valor función objetivo = -9217.41
#   Partícula 29: Valor función objetivo = -9164.44
#   Partícula 30: Valor función objetivo = -9229.42
#     Mejor local actualizado para partícula 30
# Mejor valor global hasta ahora: 9232.58
#
# --- Iteración 15/100 ---
#   Partícula 1: Valor función objetivo = -9231.02
#     Mejor local actualizado para partícula 1
#   Partícula 2: Valor función objetivo = -9193.09
#   Partícula 3: Valor función objetivo = -9222.77
#   Partícula 4: Valor función objetivo = -9167.93
#   Partícula 5: Valor función objetivo = -9186.31
#   Partícula 6: Valor función objetivo = -9180.21
#   Partícula 7: Valor función objetivo = -9194.95
#   Partícula 8: Valor función objetivo = -9223.33
#   Partícula 9: Valor función objetivo = -9224.86
#   Partícula 10: Valor función objetivo = -9224.70
#   Partícula 11: Valor función objetivo = -9201.92
#   Partícula 12: Valor función objetivo = -9220.68
#   Partícula 13: Valor función objetivo = -9207.04
#   Partícula 14: Valor función objetivo = -9215.23
#   Partícula 15: Valor función objetivo = -9226.60
#     Mejor local actualizado para partícula 15
#   Partícula 16: Valor función objetivo = -9203.39
#   Partícula 17: Valor función objetivo = -9217.92
#   Partícula 18: Valor función objetivo = -9226.12
#     Mejor local actualizado para partícula 18
#   Partícula 19: Valor función objetivo = -9206.37
#   Partícula 20: Valor función objetivo = -9217.48
#   Partícula 21: Valor función objetivo = -9200.42
#   Partícula 22: Valor función objetivo = -9221.44
#   Partícula 23: Valor función objetivo = -9223.33
#   Partícula 24: Valor función objetivo = -9199.19
#   Partícula 25: Valor función objetivo = -9214.67
#   Partícula 26: Valor función objetivo = -9214.10
#     Mejor local actualizado para partícula 26
#   Partícula 27: Valor función objetivo = -9230.05
#     Mejor local actualizado para partícula 27
#   Partícula 28: Valor función objetivo = -9224.11
#     Mejor local actualizado para partícula 28
#   Partícula 29: Valor función objetivo = -9202.25
#   Partícula 30: Valor función objetivo = -9228.44
# Mejor valor global hasta ahora: 9232.58
#
# --- Iteración 16/100 ---
#   Partícula 1: Valor función objetivo = -9205.99
#   Partícula 2: Valor función objetivo = -9156.50
#   Partícula 3: Valor función objetivo = -9227.61
#     Mejor local actualizado para partícula 3
#   Partícula 4: Valor función objetivo = -9202.69
#   Partícula 5: Valor función objetivo = -9224.35
#   Partícula 6: Valor función objetivo = -9177.29
#   Partícula 7: Valor función objetivo = -9229.03
#     Mejor local actualizado para partícula 7
#   Partícula 8: Valor función objetivo = -9230.76
#   Partícula 9: Valor función objetivo = -9221.61
#   Partícula 10: Valor función objetivo = -9227.41
#   Partícula 11: Valor función objetivo = -9229.55
#   Partícula 12: Valor función objetivo = -9223.02
#   Partícula 13: Valor función objetivo = -9143.44
#   Partícula 14: Valor función objetivo = -9228.28
#     Mejor local actualizado para partícula 14
#   Partícula 15: Valor función objetivo = -9225.75
#   Partícula 16: Valor función objetivo = -9226.35
#   Partícula 17: Valor función objetivo = -9153.34
#   Partícula 18: Valor función objetivo = -9230.14
#     Mejor local actualizado para partícula 18
#   Partícula 19: Valor función objetivo = -9192.42
#   Partícula 20: Valor función objetivo = -9212.57
#   Partícula 21: Valor función objetivo = -9231.47
#     Mejor local actualizado para partícula 21
#   Partícula 22: Valor función objetivo = -9134.60
#   Partícula 23: Valor función objetivo = -9208.48
#   Partícula 24: Valor función objetivo = -9208.31
#   Partícula 25: Valor función objetivo = -9224.88
#   Partícula 26: Valor función objetivo = -9151.21
#   Partícula 27: Valor función objetivo = -9210.66
#   Partícula 28: Valor función objetivo = -9218.79
#   Partícula 29: Valor función objetivo = -9204.13
#   Partícula 30: Valor función objetivo = -9230.92
#     Mejor local actualizado para partícula 30
# Mejor valor global hasta ahora: 9232.58
#
# --- Iteración 17/100 ---
#   Partícula 1: Valor función objetivo = -9225.81
#   Partícula 2: Valor función objetivo = -9224.66
#   Partícula 3: Valor función objetivo = -9224.61
#   Partícula 4: Valor función objetivo = -9166.82
#   Partícula 5: Valor función objetivo = -9214.45
#   Partícula 6: Valor función objetivo = -9192.78
#   Partícula 7: Valor función objetivo = -9212.43
#   Partícula 8: Valor función objetivo = -9227.77
#   Partícula 9: Valor función objetivo = -9231.42
#     Mejor local actualizado para partícula 9
#   Partícula 10: Valor función objetivo = -9202.82
#   Partícula 11: Valor función objetivo = -9209.46
#   Partícula 12: Valor función objetivo = -9205.89
#   Partícula 13: Valor función objetivo = -9130.06
#   Partícula 14: Valor función objetivo = -9213.85
#   Partícula 15: Valor función objetivo = -9226.09
#   Partícula 16: Valor función objetivo = -9185.90
#   Partícula 17: Valor función objetivo = -9184.58
#   Partícula 18: Valor función objetivo = -9218.28
#   Partícula 19: Valor función objetivo = -9217.61
#   Partícula 20: Valor función objetivo = -9207.18
#   Partícula 21: Valor función objetivo = -9207.49
#   Partícula 22: Valor función objetivo = -9123.14
#   Partícula 23: Valor función objetivo = -9227.71
#     Mejor local actualizado para partícula 23
#   Partícula 24: Valor función objetivo = -9166.64
#   Partícula 25: Valor función objetivo = -9222.22
#   Partícula 26: Valor función objetivo = -9146.96
#   Partícula 27: Valor función objetivo = -9224.20
#   Partícula 28: Valor función objetivo = -9226.77
#     Mejor local actualizado para partícula 28
#   Partícula 29: Valor función objetivo = -9203.67
#   Partícula 30: Valor función objetivo = -9228.68
# Mejor valor global hasta ahora: 9232.58
#
# --- Iteración 18/100 ---
#   Partícula 1: Valor función objetivo = -9221.69
#   Partícula 2: Valor función objetivo = -9206.68
#   Partícula 3: Valor función objetivo = -9221.70
#   Partícula 4: Valor función objetivo = -9211.14
#   Partícula 5: Valor función objetivo = -9226.97
#   Partícula 6: Valor función objetivo = -9211.57
#   Partícula 7: Valor función objetivo = -9226.22
#   Partícula 8: Valor función objetivo = -9228.51
#   Partícula 9: Valor función objetivo = -9231.78
#     Mejor local actualizado para partícula 9
#   Partícula 10: Valor función objetivo = -9229.82
#     Mejor local actualizado para partícula 10
#   Partícula 11: Valor función objetivo = -9225.54
#   Partícula 12: Valor función objetivo = -9208.23
#   Partícula 13: Valor función objetivo = -9217.65
#     Mejor local actualizado para partícula 13
#   Partícula 14: Valor función objetivo = -9231.00
#     Mejor local actualizado para partícula 14
#   Partícula 15: Valor función objetivo = -9229.28
#     Mejor local actualizado para partícula 15
#   Partícula 16: Valor función objetivo = -9189.46
#   Partícula 17: Valor función objetivo = -9223.61
#   Partícula 18: Valor función objetivo = -9210.66
#   Partícula 19: Valor función objetivo = -9227.15
#   Partícula 20: Valor función objetivo = -9201.72
#   Partícula 21: Valor función objetivo = -9225.18
#   Partícula 22: Valor función objetivo = -9214.56
#   Partícula 23: Valor función objetivo = -9224.70
#   Partícula 24: Valor función objetivo = -9224.98
#     Mejor local actualizado para partícula 24
#   Partícula 25: Valor función objetivo = -9223.32
#   Partícula 26: Valor función objetivo = -9219.72
#     Mejor local actualizado para partícula 26
#   Partícula 27: Valor función objetivo = -9215.06
#   Partícula 28: Valor función objetivo = -9228.68
#     Mejor local actualizado para partícula 28
#   Partícula 29: Valor función objetivo = -9218.65
#     Mejor local actualizado para partícula 29
#   Partícula 30: Valor función objetivo = -9227.43
# Mejor valor global hasta ahora: 9232.58
#
# --- Iteración 19/100 ---
#   Partícula 1: Valor función objetivo = -9229.56
#   Partícula 2: Valor función objetivo = -9194.13
#   Partícula 3: Valor función objetivo = -9229.15
#     Mejor local actualizado para partícula 3
#   Partícula 4: Valor función objetivo = -9178.51
#   Partícula 5: Valor función objetivo = -9213.25
#   Partícula 6: Valor función objetivo = -9219.83
#     Mejor local actualizado para partícula 6
#   Partícula 7: Valor función objetivo = -9208.84
#   Partícula 8: Valor función objetivo = -9231.12
#   Partícula 9: Valor función objetivo = -9229.62
#   Partícula 10: Valor función objetivo = -9221.31
#   Partícula 11: Valor función objetivo = -9231.08
#   Partícula 12: Valor función objetivo = -9232.33
#     Mejor local actualizado para partícula 12
#   Partícula 13: Valor función objetivo = -9182.88
#   Partícula 14: Valor función objetivo = -9215.83
#   Partícula 15: Valor función objetivo = -9232.16
#     Mejor local actualizado para partícula 15
#   Partícula 16: Valor función objetivo = -9192.33
#   Partícula 17: Valor función objetivo = -9228.81
#     Mejor local actualizado para partícula 17
#   Partícula 18: Valor función objetivo = -9228.40
#   Partícula 19: Valor función objetivo = -9227.40
#   Partícula 20: Valor función objetivo = -9220.56
#   Partícula 21: Valor función objetivo = -9232.37
#     Mejor local actualizado para partícula 21
#   Partícula 22: Valor función objetivo = -9206.77
#   Partícula 23: Valor función objetivo = -9231.91
#     Mejor local actualizado para partícula 23
#   Partícula 24: Valor función objetivo = -9223.35
#   Partícula 25: Valor función objetivo = -9230.61
#     Mejor local actualizado para partícula 25
#   Partícula 26: Valor función objetivo = -9201.09
#   Partícula 27: Valor función objetivo = -9212.30
#   Partícula 28: Valor función objetivo = -9231.19
#     Mejor local actualizado para partícula 28
#   Partícula 29: Valor función objetivo = -9221.44
#     Mejor local actualizado para partícula 29
#   Partícula 30: Valor función objetivo = -9228.90
# Mejor valor global hasta ahora: 9232.58
#
# --- Iteración 20/100 ---
#   Partícula 1: Valor función objetivo = -9215.97
#   Partícula 2: Valor función objetivo = -9203.68
#   Partícula 3: Valor función objetivo = -9228.90
#   Partícula 4: Valor función objetivo = -9190.29
#   Partícula 5: Valor función objetivo = -9232.46
#     Mejor local actualizado para partícula 5
#   Partícula 6: Valor función objetivo = -9215.20
#   Partícula 7: Valor función objetivo = -9227.24
#   Partícula 8: Valor función objetivo = -9232.51
#   Partícula 9: Valor función objetivo = -9232.48
#     Mejor local actualizado para partícula 9
#   Partícula 10: Valor función objetivo = -9218.51
#   Partícula 11: Valor función objetivo = -9221.37
#   Partícula 12: Valor función objetivo = -9211.87
#   Partícula 13: Valor función objetivo = -9191.53
#   Partícula 14: Valor función objetivo = -9224.91
#   Partícula 15: Valor función objetivo = -9226.02
#   Partícula 16: Valor función objetivo = -9209.87
#   Partícula 17: Valor función objetivo = -9230.16
#     Mejor local actualizado para partícula 17
#   Partícula 18: Valor función objetivo = -9228.00
#   Partícula 19: Valor función objetivo = -9228.51
#     Mejor local actualizado para partícula 19
#   Partícula 20: Valor función objetivo = -9229.30
#     Mejor local actualizado para partícula 20
#   Partícula 21: Valor función objetivo = -9219.21
#   Partícula 22: Valor función objetivo = -9230.62
#     Mejor local actualizado para partícula 22
#   Partícula 23: Valor función objetivo = -9232.65
#     Mejor local actualizado para partícula 23
#     Nuevo mejor global encontrado por partícula 23
#   Partícula 24: Valor función objetivo = -9232.05
#     Mejor local actualizado para partícula 24
#   Partícula 25: Valor función objetivo = -9209.82
#   Partícula 26: Valor función objetivo = -9205.29
#   Partícula 27: Valor función objetivo = -9232.62
#     Mejor local actualizado para partícula 27
#   Partícula 28: Valor función objetivo = -9231.75
#     Mejor local actualizado para partícula 28
#   Partícula 29: Valor función objetivo = -9223.36
#     Mejor local actualizado para partícula 29
#   Partícula 30: Valor función objetivo = -9224.62
# Mejor valor global hasta ahora: 9232.65
#
# --- Iteración 21/100 ---
#   Partícula 1: Valor función objetivo = -9222.78
#   Partícula 2: Valor función objetivo = -9211.86
#   Partícula 3: Valor función objetivo = -9231.06
#     Mejor local actualizado para partícula 3
#   Partícula 4: Valor función objetivo = -9169.53
#   Partícula 5: Valor función objetivo = -9228.29
#   Partícula 6: Valor función objetivo = -9224.13
#     Mejor local actualizado para partícula 6
#   Partícula 7: Valor función objetivo = -9230.39
#     Mejor local actualizado para partícula 7
#   Partícula 8: Valor función objetivo = -9229.93
#   Partícula 9: Valor función objetivo = -9231.39
#   Partícula 10: Valor función objetivo = -9226.15
#   Partícula 11: Valor función objetivo = -9225.31
#   Partícula 12: Valor función objetivo = -9229.66
#   Partícula 13: Valor función objetivo = -9134.39
#   Partícula 14: Valor función objetivo = -9213.62
#   Partícula 15: Valor función objetivo = -9226.11
#   Partícula 16: Valor función objetivo = -9220.54
#   Partícula 17: Valor función objetivo = -9227.13
#   Partícula 18: Valor función objetivo = -9232.16
#     Mejor local actualizado para partícula 18
#   Partícula 19: Valor función objetivo = -9226.26
#   Partícula 20: Valor función objetivo = -9226.62
#   Partícula 21: Valor función objetivo = -9231.61
#   Partícula 22: Valor función objetivo = -9216.09
#   Partícula 23: Valor función objetivo = -9231.25
#   Partícula 24: Valor función objetivo = -9221.47
#   Partícula 25: Valor función objetivo = -9215.55
#   Partícula 26: Valor función objetivo = -9164.16
#   Partícula 27: Valor función objetivo = -9217.90
#   Partícula 28: Valor función objetivo = -9227.29
#   Partícula 29: Valor función objetivo = -9218.41
#   Partícula 30: Valor función objetivo = -9221.97
# Mejor valor global hasta ahora: 9232.65
#
# --- Iteración 22/100 ---
#   Partícula 1: Valor función objetivo = -9218.49
#   Partícula 2: Valor función objetivo = -9224.87
#   Partícula 3: Valor función objetivo = -9212.51
#   Partícula 4: Valor función objetivo = -9221.24
#   Partícula 5: Valor función objetivo = -9223.35
#   Partícula 6: Valor función objetivo = -9223.81
#   Partícula 7: Valor función objetivo = -9221.43
#   Partícula 8: Valor función objetivo = -9231.82
#   Partícula 9: Valor función objetivo = -9231.38
#   Partícula 10: Valor función objetivo = -9220.58
#   Partícula 11: Valor función objetivo = -9231.27
#   Partícula 12: Valor función objetivo = -9223.58
#   Partícula 13: Valor función objetivo = -9125.34
#   Partícula 14: Valor función objetivo = -9219.58
#   Partícula 15: Valor función objetivo = -9232.11
#   Partícula 16: Valor función objetivo = -9214.69
#   Partícula 17: Valor función objetivo = -9226.70
#   Partícula 18: Valor función objetivo = -9223.29
#   Partícula 19: Valor función objetivo = -9227.05
#   Partícula 20: Valor función objetivo = -9224.97
#   Partícula 21: Valor función objetivo = -9221.00
#   Partícula 22: Valor función objetivo = -9203.89
#   Partícula 23: Valor función objetivo = -9230.02
#   Partícula 24: Valor función objetivo = -9220.53
#   Partícula 25: Valor función objetivo = -9224.71
#   Partícula 26: Valor función objetivo = -9203.06
#   Partícula 27: Valor función objetivo = -9220.36
#   Partícula 28: Valor función objetivo = -9232.05
#     Mejor local actualizado para partícula 28
#   Partícula 29: Valor función objetivo = -9230.35
#     Mejor local actualizado para partícula 29
#   Partícula 30: Valor función objetivo = -9223.97
# Mejor valor global hasta ahora: 9232.65
#
# --- Iteración 23/100 ---
#   Partícula 1: Valor función objetivo = -9230.04
#   Partícula 2: Valor función objetivo = -9225.47
#   Partícula 3: Valor función objetivo = -9219.86
#   Partícula 4: Valor función objetivo = -9203.48
#   Partícula 5: Valor función objetivo = -9223.21
# ...
#     Mejor local actualizado para partícula 4
#   Partícula 5: Valor función objetivo = -9233.08
#   Partícula 6: Valor función objetivo = -9233.09
#   Partícula 7: Valor función objetivo = -9233.09
#     Mejor local actualizado para partícula 7
#   Partícula 8: Valor función objetivo = -9233.09
#   Partícula 9: Valor función objetivo = -9233.08
#   Partícula 10: Valor función objetivo = -9233.09
#   Partícula 11: Valor función objetivo = -9233.09
#   Partícula 12: Valor función objetivo = -9233.09
#   Partícula 13: Valor función objetivo = -9233.09
#   Partícula 14: Valor función objetivo = -9233.09
#     Mejor local actualizado para partícula 14
#   Partícula 15: Valor función objetivo = -9233.08
#   Partícula 16: Valor función objetivo = -9233.08
#   Partícula 17: Valor función objetivo = -9233.09
#   Partícula 18: Valor función objetivo = -9233.09
#   Partícula 19: Valor función objetivo = -9233.09
#     Mejor local actualizado para partícula 19
#   Partícula 20: Valor función objetivo = -9233.05
#   Partícula 21: Valor función objetivo = -9232.98
#   Partícula 22: Valor función objetivo = -9233.09
#     Mejor local actualizado para partícula 22
#   Partícula 23: Valor función objetivo = -9233.07
#   Partícula 24: Valor función objetivo = -9233.07
#   Partícula 25: Valor función objetivo = -9233.04
#   Partícula 26: Valor función objetivo = -9233.08
#   Partícula 27: Valor función objetivo = -9233.09
#   Partícula 28: Valor función objetivo = -9233.09
#   Partícula 29: Valor función objetivo = -9233.09
#   Partícula 30: Valor función objetivo = -9233.08
# Mejor valor global hasta ahora: 9233.10
#
# --- Iteración 93/100 ---
#   Partícula 1: Valor función objetivo = -9233.09
#   Partícula 2: Valor función objetivo = -9233.02
#   Partícula 3: Valor función objetivo = -9233.10
#     Mejor local actualizado para partícula 3
#   Partícula 4: Valor función objetivo = -9233.09
#   Partícula 5: Valor función objetivo = -9233.07
#   Partícula 6: Valor función objetivo = -9233.09
#   Partícula 7: Valor función objetivo = -9233.09
#     Mejor local actualizado para partícula 7
#   Partícula 8: Valor función objetivo = -9233.08
#   Partícula 9: Valor función objetivo = -9233.08
#   Partícula 10: Valor función objetivo = -9233.09
#   Partícula 11: Valor función objetivo = -9233.09
#     Mejor local actualizado para partícula 11
#   Partícula 12: Valor función objetivo = -9233.09
#   Partícula 13: Valor función objetivo = -9233.09
#   Partícula 14: Valor función objetivo = -9233.09
#   Partícula 15: Valor función objetivo = -9233.09
#   Partícula 16: Valor función objetivo = -9233.09
#   Partícula 17: Valor función objetivo = -9233.10
#     Mejor local actualizado para partícula 17
#     Nuevo mejor global encontrado por partícula 17
#   Partícula 18: Valor función objetivo = -9233.09
#   Partícula 19: Valor función objetivo = -9233.09
#   Partícula 20: Valor función objetivo = -9233.04
#   Partícula 21: Valor función objetivo = -9233.00
#   Partícula 22: Valor función objetivo = -9233.08
#   Partícula 23: Valor función objetivo = -9233.06
#   Partícula 24: Valor función objetivo = -9233.08
#   Partícula 25: Valor función objetivo = -9233.04
#   Partícula 26: Valor función objetivo = -9233.07
#   Partícula 27: Valor función objetivo = -9233.08
#   Partícula 28: Valor función objetivo = -9233.05
#   Partícula 29: Valor función objetivo = -9233.09
#   Partícula 30: Valor función objetivo = -9233.09
# Mejor valor global hasta ahora: 9233.10
#
# --- Iteración 94/100 ---
#   Partícula 1: Valor función objetivo = -9233.09
#   Partícula 2: Valor función objetivo = -9233.09
#   Partícula 3: Valor función objetivo = -9233.09
#   Partícula 4: Valor función objetivo = -9233.09
#   Partícula 5: Valor función objetivo = -9233.09
#   Partícula 6: Valor función objetivo = -9233.09
#   Partícula 7: Valor función objetivo = -9233.09
#   Partícula 8: Valor función objetivo = -9233.09
#   Partícula 9: Valor función objetivo = -9233.07
#   Partícula 10: Valor función objetivo = -9233.08
#   Partícula 11: Valor función objetivo = -9233.08
#   Partícula 12: Valor función objetivo = -9233.09
#   Partícula 13: Valor función objetivo = -9233.09
#   Partícula 14: Valor función objetivo = -9233.10
#     Mejor local actualizado para partícula 14
#   Partícula 15: Valor función objetivo = -9233.08
#   Partícula 16: Valor función objetivo = -9233.08
#   Partícula 17: Valor función objetivo = -9233.09
#   Partícula 18: Valor función objetivo = -9233.08
#   Partícula 19: Valor función objetivo = -9233.09
#   Partícula 20: Valor función objetivo = -9233.06
#   Partícula 21: Valor función objetivo = -9232.92
#   Partícula 22: Valor función objetivo = -9233.08
#   Partícula 23: Valor función objetivo = -9233.05
#   Partícula 24: Valor función objetivo = -9233.07
#   Partícula 25: Valor función objetivo = -9233.06
#     Mejor local actualizado para partícula 25
#   Partícula 26: Valor función objetivo = -9233.08
#   Partícula 27: Valor función objetivo = -9233.08
#   Partícula 28: Valor función objetivo = -9233.07
#   Partícula 29: Valor función objetivo = -9233.09
#   Partícula 30: Valor función objetivo = -9233.07
# Mejor valor global hasta ahora: 9233.10
#
# --- Iteración 95/100 ---
#   Partícula 1: Valor función objetivo = -9233.09
#   Partícula 2: Valor función objetivo = -9233.04
#   Partícula 3: Valor función objetivo = -9233.09
#   Partícula 4: Valor función objetivo = -9233.09
#   Partícula 5: Valor función objetivo = -9233.08
#   Partícula 6: Valor función objetivo = -9233.08
#   Partícula 7: Valor función objetivo = -9233.09
#   Partícula 8: Valor función objetivo = -9233.08
#   Partícula 9: Valor función objetivo = -9233.06
#   Partícula 10: Valor función objetivo = -9233.09
#   Partícula 11: Valor función objetivo = -9233.08
#   Partícula 12: Valor función objetivo = -9233.09
#   Partícula 13: Valor función objetivo = -9233.09
#   Partícula 14: Valor función objetivo = -9233.09
#   Partícula 15: Valor función objetivo = -9233.09
#   Partícula 16: Valor función objetivo = -9233.08
#   Partícula 17: Valor función objetivo = -9233.09
#   Partícula 18: Valor función objetivo = -9233.08
#   Partícula 19: Valor función objetivo = -9233.09
#   Partícula 20: Valor función objetivo = -9233.08
#   Partícula 21: Valor función objetivo = -9233.07
#   Partícula 22: Valor función objetivo = -9233.08
#   Partícula 23: Valor función objetivo = -9233.06
#   Partícula 24: Valor función objetivo = -9233.09
#     Mejor local actualizado para partícula 24
#   Partícula 25: Valor función objetivo = -9233.08
#     Mejor local actualizado para partícula 25
#   Partícula 26: Valor función objetivo = -9233.09
#     Mejor local actualizado para partícula 26
#   Partícula 27: Valor función objetivo = -9233.09
#   Partícula 28: Valor función objetivo = -9233.09
#   Partícula 29: Valor función objetivo = -9233.08
#   Partícula 30: Valor función objetivo = -9233.08
# Mejor valor global hasta ahora: 9233.10
#
# --- Iteración 96/100 ---
#   Partícula 1: Valor función objetivo = -9233.09
#     Mejor local actualizado para partícula 1
#   Partícula 2: Valor función objetivo = -9233.07
#   Partícula 3: Valor función objetivo = -9233.09
#   Partícula 4: Valor función objetivo = -9233.08
#   Partícula 5: Valor función objetivo = -9233.09
#   Partícula 6: Valor función objetivo = -9233.09
#   Partícula 7: Valor función objetivo = -9233.09
#   Partícula 8: Valor función objetivo = -9233.08
#   Partícula 9: Valor función objetivo = -9233.08
#   Partícula 10: Valor función objetivo = -9233.09
#   Partícula 11: Valor función objetivo = -9233.09
#   Partícula 12: Valor función objetivo = -9233.09
#   Partícula 13: Valor función objetivo = -9233.09
#   Partícula 14: Valor función objetivo = -9233.09
#   Partícula 15: Valor función objetivo = -9233.09
#   Partícula 16: Valor función objetivo = -9233.08
#   Partícula 17: Valor función objetivo = -9233.09
#   Partícula 18: Valor función objetivo = -9233.09
#     Mejor local actualizado para partícula 18
#   Partícula 19: Valor función objetivo = -9233.09
#   Partícula 20: Valor función objetivo = -9233.09
#   Partícula 21: Valor función objetivo = -9232.96
#   Partícula 22: Valor función objetivo = -9233.09
#   Partícula 23: Valor función objetivo = -9233.09
#     Mejor local actualizado para partícula 23
#   Partícula 24: Valor función objetivo = -9233.09
#   Partícula 25: Valor función objetivo = -9233.08
#     Mejor local actualizado para partícula 25
#   Partícula 26: Valor función objetivo = -9233.08
#   Partícula 27: Valor función objetivo = -9233.08
#   Partícula 28: Valor función objetivo = -9233.08
#   Partícula 29: Valor función objetivo = -9233.07
#   Partícula 30: Valor función objetivo = -9233.09
# Mejor valor global hasta ahora: 9233.10
#
# --- Iteración 97/100 ---
#   Partícula 1: Valor función objetivo = -9233.09
#   Partícula 2: Valor función objetivo = -9233.08
#   Partícula 3: Valor función objetivo = -9233.09
#   Partícula 4: Valor función objetivo = -9233.09
#   Partícula 5: Valor función objetivo = -9233.09
#   Partícula 6: Valor función objetivo = -9233.09
#   Partícula 7: Valor función objetivo = -9233.09
#   Partícula 8: Valor función objetivo = -9233.09
#   Partícula 9: Valor función objetivo = -9233.09
#   Partícula 10: Valor función objetivo = -9233.09
#     Mejor local actualizado para partícula 10
#   Partícula 11: Valor función objetivo = -9233.08
#   Partícula 12: Valor función objetivo = -9233.09
#   Partícula 13: Valor función objetivo = -9233.09
#   Partícula 14: Valor función objetivo = -9233.09
#   Partícula 15: Valor función objetivo = -9233.09
#   Partícula 16: Valor función objetivo = -9233.09
#   Partícula 17: Valor función objetivo = -9233.10
#   Partícula 18: Valor función objetivo = -9233.09
#   Partícula 19: Valor función objetivo = -9233.09
#     Mejor local actualizado para partícula 19
#   Partícula 20: Valor función objetivo = -9233.09
#     Mejor local actualizado para partícula 20
#   Partícula 21: Valor función objetivo = -9233.07
#   Partícula 22: Valor función objetivo = -9233.09
#   Partícula 23: Valor función objetivo = -9233.07
#   Partícula 24: Valor función objetivo = -9233.09
#     Mejor local actualizado para partícula 24
#   Partícula 25: Valor función objetivo = -9233.06
#   Partícula 26: Valor función objetivo = -9233.09
#   Partícula 27: Valor función objetivo = -9233.09
#   Partícula 28: Valor función objetivo = -9233.08
#   Partícula 29: Valor función objetivo = -9233.07
#   Partícula 30: Valor función objetivo = -9233.09
# Mejor valor global hasta ahora: 9233.10
#
# --- Iteración 98/100 ---
#   Partícula 1: Valor función objetivo = -9233.09
#   Partícula 2: Valor función objetivo = -9233.07
#   Partícula 3: Valor función objetivo = -9233.10
#     Mejor local actualizado para partícula 3
#   Partícula 4: Valor función objetivo = -9233.09
#   Partícula 5: Valor función objetivo = -9233.09
#   Partícula 6: Valor función objetivo = -9233.09
#   Partícula 7: Valor función objetivo = -9233.09
#   Partícula 8: Valor función objetivo = -9233.08
#   Partícula 9: Valor función objetivo = -9233.09
#   Partícula 10: Valor función objetivo = -9233.09
#   Partícula 11: Valor función objetivo = -9233.09
#   Partícula 12: Valor función objetivo = -9233.09
#     Mejor local actualizado para partícula 12
#   Partícula 13: Valor función objetivo = -9233.08
#   Partícula 14: Valor función objetivo = -9233.09
#   Partícula 15: Valor función objetivo = -9233.09
#   Partícula 16: Valor función objetivo = -9233.09
#     Mejor local actualizado para partícula 16
#   Partícula 17: Valor función objetivo = -9233.09
#   Partícula 18: Valor función objetivo = -9233.08
#   Partícula 19: Valor función objetivo = -9233.08
#   Partícula 20: Valor función objetivo = -9233.09
#   Partícula 21: Valor función objetivo = -9233.04
#   Partícula 22: Valor función objetivo = -9233.08
#   Partícula 23: Valor función objetivo = -9233.09
#   Partícula 24: Valor función objetivo = -9233.09
#   Partícula 25: Valor función objetivo = -9233.07
#   Partícula 26: Valor función objetivo = -9233.09
#   Partícula 27: Valor función objetivo = -9233.08
#   Partícula 28: Valor función objetivo = -9233.09
#   Partícula 29: Valor función objetivo = -9233.07
#   Partícula 30: Valor función objetivo = -9233.09
# Mejor valor global hasta ahora: 9233.10
#
# --- Iteración 99/100 ---
#   Partícula 1: Valor función objetivo = -9233.10
#     Mejor local actualizado para partícula 1
#   Partícula 2: Valor función objetivo = -9233.09
#   Partícula 3: Valor función objetivo = -9233.09
#   Partícula 4: Valor función objetivo = -9233.09
#   Partícula 5: Valor función objetivo = -9233.09
#   Partícula 6: Valor función objetivo = -9233.09
#   Partícula 7: Valor función objetivo = -9233.09
#   Partícula 8: Valor función objetivo = -9233.09
#   Partícula 9: Valor función objetivo = -9233.08
#   Partícula 10: Valor función objetivo = -9233.09
#   Partícula 11: Valor función objetivo = -9233.09
#     Mejor local actualizado para partícula 11
#   Partícula 12: Valor función objetivo = -9233.09
#   Partícula 13: Valor función objetivo = -9233.09
#   Partícula 14: Valor función objetivo = -9233.09
#   Partícula 15: Valor función objetivo = -9233.08
#   Partícula 16: Valor función objetivo = -9233.08
#   Partícula 17: Valor función objetivo = -9233.09
#   Partícula 18: Valor función objetivo = -9233.09
#   Partícula 19: Valor función objetivo = -9233.08
#   Partícula 20: Valor función objetivo = -9233.08
#   Partícula 21: Valor función objetivo = -9233.06
#   Partícula 22: Valor función objetivo = -9233.09
#   Partícula 23: Valor función objetivo = -9233.09
#   Partícula 24: Valor función objetivo = -9233.09
#     Mejor local actualizado para partícula 24
#   Partícula 25: Valor función objetivo = -9233.08
#   Partícula 26: Valor función objetivo = -9233.09
#   Partícula 27: Valor función objetivo = -9233.08
#   Partícula 28: Valor función objetivo = -9233.09
#   Partícula 29: Valor función objetivo = -9233.08
#   Partícula 30: Valor función objetivo = -9233.09
#     Mejor local actualizado para partícula 30
# Mejor valor global hasta ahora: 9233.10
#
# --- Iteración 100/100 ---
#   Partícula 1: Valor función objetivo = -9233.10
#   Partícula 2: Valor función objetivo = -9233.09
#   Partícula 3: Valor función objetivo = -9233.09
#   Partícula 4: Valor función objetivo = -9233.10
#     Mejor local actualizado para partícula 4
#   Partícula 5: Valor función objetivo = -9233.09
#     Mejor local actualizado para partícula 5
#   Partícula 6: Valor función objetivo = -9233.09
#   Partícula 7: Valor función objetivo = -9233.09
#   Partícula 8: Valor función objetivo = -9233.08
#   Partícula 9: Valor función objetivo = -9233.09
#   Partícula 10: Valor función objetivo = -9233.08
#   Partícula 11: Valor función objetivo = -9233.09
#   Partícula 12: Valor función objetivo = -9233.08
#   Partícula 13: Valor función objetivo = -9233.10
#   Partícula 14: Valor función objetivo = -9233.09
#   Partícula 15: Valor función objetivo = -9233.09
#   Partícula 16: Valor función objetivo = -9233.08
#   Partícula 17: Valor función objetivo = -9233.09
#   Partícula 18: Valor función objetivo = -9233.09
#   Partícula 19: Valor función objetivo = -9233.10
#     Mejor local actualizado para partícula 19
#   Partícula 20: Valor función objetivo = -9233.08
#   Partícula 21: Valor función objetivo = -9233.06
#   Partícula 22: Valor función objetivo = -9233.09
#   Partícula 23: Valor función objetivo = -9233.09
#   Partícula 24: Valor función objetivo = -9233.08
#   Partícula 25: Valor función objetivo = -9233.05
#   Partícula 26: Valor función objetivo = -9233.09
#   Partícula 27: Valor función objetivo = -9233.08
#   Partícula 28: Valor función objetivo = -9233.09
#   Partícula 29: Valor función objetivo = -9233.09
#   Partícula 30: Valor función objetivo = -9233.09
# Mejor valor global hasta ahora: 9233.10
#
# --- Resultados finales ---
# Mejores coordenadas y radios:
# Torre 1: Posición = [ 42.90625918 100.        ], Radio = 20.00
# Torre 2: Posición = [100. 100.], Radio = 20.00
# Torre 3: Posición = [77.26658934  0.        ], Radio = 20.00
# Torre 4: Posición = [100. 100.], Radio = 0.00
# Torre 5: Posición = [19.9933288  0.       ], Radio = 0.00
# Torre 6: Posición = [100.          57.51381845], Radio = 20.00
# Torre 7: Posición = [0. 0.], Radio = 20.00
# Torre 8: Posición = [100.   0.], Radio = 20.00
# Torre 9: Posición = [39.99086872  0.        ], Radio = 20.00
# Torre 10: Posición = [  0. 100.], Radio = 20.00
# Valor final de la función objetivo (cobertura - penalizaciones): 9233.10
